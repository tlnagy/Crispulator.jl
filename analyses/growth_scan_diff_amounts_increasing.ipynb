# %% [markdown]
# ## Objective
#
# I wanted to explore the effect that different amounts of increasing genes and differing strengths of the increasing genes have on the scores in growth screens.

# %%
using DataFrames
using Gadfly
using ColorBrewer

# %%
# df = readtable("../data/test_17c6a3d_dirty.csv")
df = readtable("bigiron_growth_sensitivity_to_lib_49b2f59_clean.csv")
head(df)
# Out:
# 6×18 DataFrames.DataFrame
# │ Row │ measure │ score     │ num_genes │ coverage │ representation │ moi  │
# ├─────┼─────────┼───────────┼───────────┼──────────┼────────────────┼──────┤
# │ 1   │ "inc"   │ 0.0602038 │ 500       │ 5        │ 100            │ 0.25 │
# │ 2   │ "inc"   │ 0.227646  │ 500       │ 5        │ 100            │ 0.25 │
# │ 3   │ "inc"   │ 0.106043  │ 500       │ 5        │ 100            │ 0.25 │
# │ 4   │ "inc"   │ 0.227507  │ 500       │ 5        │ 100            │ 0.25 │
# │ 5   │ "inc"   │ 0.0882289 │ 500       │ 5        │ 100            │ 0.25 │
# │ 6   │ "inc"   │ 0.0833505 │ 500       │ 5        │ 100            │ 0.25 │
#
# │ Row │ seq_depth │ bottleneck_representation │ num_bottlenecks │ noise │
# ├─────┼───────────┼───────────────────────────┼─────────────────┼───────┤
# │ 1   │ 100       │ 100                       │ 1               │ 0.01  │
# │ 2   │ 100       │ 100                       │ 1               │ 0.01  │
# │ 3   │ 100       │ 100                       │ 1               │ 0.01  │
# │ 4   │ 100       │ 100                       │ 1               │ 0.01  │
# │ 5   │ 100       │ 100                       │ 1               │ 0.01  │
# │ 6   │ 100       │ 100                       │ 1               │ 0.01  │
#
# │ Row │ frac_hq │ mean_hq_kd │ frac_inc │ frac_dec │ cent_inc_phenotype │
# ├─────┼─────────┼────────────┼──────────┼──────────┼────────────────────┤
# │ 1   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
# │ 2   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
# │ 3   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
# │ 4   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
# │ 5   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
# │ 6   │ 0.9     │ 0.9        │ 0.02     │ 0.1      │ 0.1                │
#
# │ Row │ relationships     │ crisprtype │ run_idx │
# ├─────┼───────────────────┼────────────┼─────────┤
# │ 1   │ "linearsigmoidal" │ "CRISPRi"  │ 1       │
# │ 2   │ "linearsigmoidal" │ "CRISPRi"  │ 2       │
# │ 3   │ "linearsigmoidal" │ "CRISPRi"  │ 3       │
# │ 4   │ "linearsigmoidal" │ "CRISPRi"  │ 4       │
# │ 5   │ "linearsigmoidal" │ "CRISPRi"  │ 5       │
# │ 6   │ "linearsigmoidal" │ "CRISPRi"  │ 6       │

# %%
df[:weight_increasing] = df[:cent_inc_phenotype] .* 10 .* df[:frac_inc];

# %%
grouped_info = by(df, [:measure, :cent_inc_phenotype, :frac_inc, :crisprtype, :num_bottlenecks]) do grouped_df
    n = size(grouped_df, 1)
    mean_score = clamp(mean(grouped_df[:score]), 0, 1)
    std_score = std(grouped_df[:score])
    conf_int = 1.96 * std_score./sqrt(n)
    DataFrame(
        std_score = std_score,
        mean_score = mean_score,
        score_max = mean_score + conf_int,
        score_min = mean_score - conf_int,
        n = n
    )
end
head(grouped_info)
# Out:
# 6×10 DataFrames.DataFrame
# │ Row │ measure │ cent_inc_phenotype │ frac_inc │ crisprtype │ num_bottlenecks │
# ├─────┼─────────┼────────────────────┼──────────┼────────────┼─────────────────┤
# │ 1   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 1               │
# │ 2   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 2               │
# │ 3   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 3               │
# │ 4   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 4               │
# │ 5   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 5               │
# │ 6   │ "dec"   │ 0.1                │ 0.02     │ "CRISPRKO" │ 6               │
#
# │ Row │ std_score │ mean_score │ score_max │ score_min │ n  │
# ├─────┼───────────┼────────────┼───────────┼───────────┼────┤
# │ 1   │ 0.0810368 │ 0.484072   │ 0.515838  │ 0.452305  │ 25 │
# │ 2   │ 0.0570897 │ 0.758893   │ 0.781272  │ 0.736514  │ 25 │
# │ 3   │ 0.0381061 │ 0.864183   │ 0.879121  │ 0.849245  │ 25 │
# │ 4   │ 0.0322786 │ 0.9224     │ 0.935053  │ 0.909747  │ 25 │
# │ 5   │ 0.0221579 │ 0.942913   │ 0.951599  │ 0.934227  │ 25 │
# │ 6   │ 0.0158186 │ 0.955624   │ 0.961824  │ 0.949423  │ 25 │

# %%
p = plot(grouped_info[grouped_info[:frac_inc] .== 0.02, :], 
x=:num_bottlenecks, y=:mean_score, ymax=:score_max, ymin=:score_min, 
xgroup=:crisprtype, ygroup=:measure, color=:cent_inc_phenotype,
Geom.subplot_grid(Geom.line, Geom.ribbon, Coord.cartesian(xmin=1, ymax=1, ymin=0),
Guide.xticks(ticks=[1,5,10,15,20])),
Guide.title("Growth screens with more bottlenecks are more sensitive\n to takeover by strong increasing genes"))
filename = "../plots/growth_screen_takeover_increasing_genes"
draw(SVG("$filename.svg", 15cm, 10cm), p)
p.theme = Theme(background_color = colorant"white")
draw(PNG("$filename.png", 15cm, 10cm, dpi=300), p)
draw(SVG(15cm, 10cm), p)
# Out:
# Compose.SVG(150.0mm,100.0mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=32206, maxsize=Inf, ptr=32207, mark=-1),nothing,"img-7867fcdf",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(Compose.Property{Compose.FillPrimitive}=>nothing,Compose.Property{Compose.SVGClassPrimitive}=>nothing,Compose.Property{Compose.StrokePrimitive}=>nothing),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(25.08482801649305mm,46.87390950520833mm),(66.81808132595486mm,46.87390950520833mm),(66.81808132595486mm,72.59879014756945mm),(25.08482801649305mm,72.59879014756945mm)])=>"img-7867fcdf-24",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(12.51193033854166mm,17.149028862847217mm),(112.55133463541668mm,17.149028862847217mm),(112.55133463541668mm,85.45706380208333mm),(12.51193033854166mm,85.45706380208333mm)])=>"img-7867fcdf-9",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(70.81808132595486mm,46.87390950520833mm),(110.55133463541668mm,46.87390950520833mm),(110.55133463541668mm,72.59879014756945mm),(70.81808132595486mm,72.59879014756945mm)])=>"img-7867fcdf-16",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(70.81808132595486mm,19.149028862847217mm),(110.55133463541668mm,19.149028862847217mm),(110.55133463541668mm,42.87390950520833mm),(70.81808132595486mm,42.87390950520833mm)])=>"img-7867fcdf-34",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(25.08482801649305mm,19.149028862847217mm),(66.81808132595486mm,19.149028862847217mm),(66.81808132595486mm,42.87390950520833mm),(25.08482801649305mm,42.87390950520833mm)])=>"img-7867fcdf-42"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-7867fcdf-53",false,53,AbstractString["/Users/tamasnagy/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-7867fcdf-10\")\n   .init_gadfly();","fig.select(\"#img-7867fcdf-17\")\n   .init_gadfly();","fig.select(\"#img-7867fcdf-25\")\n   .init_gadfly();","fig.select(\"#img-7867fcdf-35\")\n   .init_gadfly();","fig.select(\"#img-7867fcdf-43\")\n   .init_gadfly();"],false,:none)
